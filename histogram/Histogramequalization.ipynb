# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

img = cv2.imread('Masa-kecil.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
plt.imshow(img),plt.title('Ori')
plt.show()

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/cdf.max()


plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'),loc = 'upper left')
plt.show()

# %%
import cv2
import numpy
 
img = cv2.imread('Masa-kecil.jpg')
img_to_yuv = cv2.cvtColor(img,cv2.COLOR_BGR2YUV)
img_to_yuv[:,:,0] = cv2.equalizeHist(img_to_yuv[:,:,0])
hist_equalization_result = cv2.cvtColor(img_to_yuv, cv2.COLOR_YUV2BGR)


cv2.imwrite('result5.jpg',hist_equalization_result)
img2 = cv2.imread('result5.jpg')
plt.imshow(img2),plt.title('New')
plt.show()

# %%
import cv2
import numpy as np

img3 = cv2.imread('result1.jpg')
median = cv2.medianBlur(img3, 5)
compare = np.concatenate((img3, median), axis=1)

cv2.imshow('img3', compare)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
 
img = cv2.imread('Masa-kecil.jpg')

img_shape = img.shape
print(img_shape)
# Out:
# (191, 300, 3)
